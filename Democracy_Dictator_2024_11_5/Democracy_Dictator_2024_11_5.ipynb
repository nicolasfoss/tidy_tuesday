# %% [markdown]
# # Democracy and Dictatorship
# ## Tidy Tuesday Week 45 for `2024-11-05`
#
# This week we will explore regime changes.
#
# Here is the source data ==> [Democracy Data](https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2024/2024-11-05/democracy_data.csv)
#
# Thanks to [Jon Harmon](https://github.com/jonthegeek) for putting these data together!
